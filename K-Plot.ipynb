# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
t1 = np.linspace(0,20,5)
t2 = np.linspace(0,4,5)
t3 = np.linspace(0,8,5)
print(t1)
m = 1000
K1 = 0.5*m*t1**2
K1 = np.array(K1)
K2 = 0.5*m*(20-5*t2)**2
K2 = np.array(K2)
K3 = 0.5*m*20**2
K3 = np.zeros([5]) + K3
print(K3)
# Out:
# [ 0.  5. 10. 15. 20.]
# [200000. 200000. 200000. 200000. 200000.]

# %%
fig = plt.figure()
plt.plot(t1,K1, marker='o')
plt.show()

# %%
plt.plot(t2,K2,marker='o')
plt.show()

# %%
plt.plot(t3,K3, marker='o')
plt.show()
